# %% [markdown]
# # Count Grid Points and Zone Cycles

# %% [markdown]
# ## Carpet

# %% [markdown]
# * physical extent: [-400,-400,-400] : [400,400,400]
# * interior extent: [-396.667,-396.667,-396.667] : [396.667,396.667,396.667]
# * exterior extent: [-406.667,-406.667,-406.667] : [406.667,406.667,406.667]

# %%
dx0 = 10/3
# Out:
# 3.3333333333333335

# %%
ExteriorGridCarpet = [
    [[245,245,245]],
    [[287,283,283]],
    [[293,283,283]],
    [[303,283,283]],
    [[297,259,259]],
    [[287,211,211]],
    [[365,211,211]],
    [[172,173,173],[172,173,173]],
    [[173,173,173],[173,173,173]],
]
# Out:
# 9-element Vector{Vector{Vector{Int64}}}:
#  [[245, 245, 245]]
#  [[287, 283, 283]]
#  [[293, 283, 283]]
#  [[303, 283, 283]]
#  [[297, 259, 259]]
#  [[287, 211, 211]]
#  [[365, 211, 211]]
#  [[172, 173, 173], [172, 173, 173]]
#  [[173, 173, 173], [173, 173, 173]]

# %% [markdown]
# #### Level 1

# %%
(406.667 - 396.667) / dx0  # There are 3 boundary points
# Out:
# 3.0

# %%
ExteriorGridCarpet[1][1] .- 6  # interior points
# Out:
# 3-element Vector{Int64}:
#  239
#  239
#  239

# %% [markdown]
# #### Level 2

# %%
ExteriorGridCarpet[2][1] .- 18
# Out:
# 3-element Vector{Int64}:
#  269
#  265
#  265

# %% [markdown]
# ### Summary

# %%
[[[ x .- 18 for x in sublist] for sublist in group] for group in ExteriorGridCarpet]
# Out:
# 9-element Vector{Vector{Vector{Int64}}}:
#  [[227, 227, 227]]
#  [[269, 265, 265]]
#  [[275, 265, 265]]
#  [[285, 265, 265]]
#  [[279, 241, 241]]
#  [[269, 193, 193]]
#  [[347, 193, 193]]
#  [[154, 155, 155], [154, 155, 155]]
#  [[155, 155, 155], [155, 155, 155]]

# %% [markdown]
# ## CarpetX

# %%
CellsCarpetX = [
    13824000,
    20123648,
    20123648,
    21307392,
    16588800,
    10027008,
    12976128,
    8192000,
    8192000,
]
# Out:
# 9-element Vector{Int64}:
#  13824000
#  20123648
#  20123648
#  21307392
#  16588800
#  10027008
#  12976128
#   8192000
#   8192000

# %%
sum(x for x in CellsCarpetX)
# Out:
# 131354624

# %% [markdown]
# **The sum here includes ghost points!!! (except at the coarsest level.)**

# %% [markdown]
# ### To Be Specific

# %% [markdown]
# #### Level 1 (400/400)

# %%
for i in 210:300
    n3 = CellsCarpetX[1] / i^2
    if isapprox(n3, round(n3); atol=1e-4) && i <= n3
        println(i, "x", i, "x", Int(round(n3)))
    end
end
# Out:
# 240x240x240

# %% [markdown]
# #### Level 2 (220/200) and Level 3 (110/50)

# %%
240 * 220 / 200
# Out:
# 264.0

# %%
for i in 210:300
    n3 = CellsCarpetX[2] / i^2
    if isapprox(n3, round(n3); atol=1e-4) && i <= n3
        println(i, "x", i, "x", Int(round(n3)))
    end
end
# Out:
# 272x272x272

# %%
for i in 210:300
    n3 = CellsCarpetX[3] / i^2
    if isapprox(n3, round(n3); atol=1e-4) && i <= n3
        println(i, "x", i, "x", Int(round(n3)))
    end
end
# Out:
# 272x272x272

# %% [markdown]
# #### Level 4 (55/50)

# %%
240 * 55 / 50
# Out:
# 264.0

# %%
for i in 210:300
    n3 = CellsCarpetX[4] / i^2
    if isapprox(n3, round(n3); atol=1e-4) && i <= n3
        println(i, "x", i, "x", Int(round(n3)))
    end
end
# Out:
# 272x272x288

# %% [markdown]
# #### Level 5 (25/25)

# %%
240 * 25 / 25
# Out:
# 240.0

# %%
for i in 210:300
    n3 = CellsCarpetX[5] / i^2
    if isapprox(n3, round(n3); atol=1e-4) && i <= n3
        println(i, "x", i, "x", Int(round(n3)))
    end
end
# Out:
# 240x240x288

# %% [markdown]
# #### Level 6 (10/12.5)

# %%
240 * 10 / 12.5
# Out:
# 192.0

# %%
for i in 180:300
    n3 = CellsCarpetX[6] / i^2
    if isapprox(n3, round(n3); atol=1e-4) && i <= n3
        println(i, "x", i, "x", Int(round(n3)))
    end
end
# Out:
# 192x192x272

# %% [markdown]
# #### Level 7 (5/6.25)

# %%
240 * 5 / 6.25
# Out:
# 192.0

# %%
for i in 180:300
    n3 = CellsCarpetX[7] / i^2
    if isapprox(n3, round(n3); atol=1e-4) && i <= n3
        println(i, "x", i, "x", Int(round(n3)))
    end
end
# Out:
# 192x192x352

# %% [markdown]
# #### Level 8 (4) and Level 9 (4)

# %%
for i in 150:300
    n3 = (CellsCarpetX[8]/2) / i^2
    if isapprox(n3, round(n3); atol=1e-4) && i <= n3
        println(i, "x", i, "x", Int(round(n3)))
    end
end
# Out:
# 160x160x160

# %%
for i in 150:300
    n3 = (CellsCarpetX[9]/2) / i^2
    if isapprox(n3, round(n3); atol=1e-4) && i <= n3
        println(i, "x", i, "x", Int(round(n3)))
    end
end
# Out:
# 160x160x160
